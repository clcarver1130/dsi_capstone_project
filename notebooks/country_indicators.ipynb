# %%
# Load in data set: df
import pandas as pd
df = pd.read_csv('Data_Extract_From_World_Development_Indicators/7ba61dfd-d031-466d-a5d6-42cb11b3e281_Data.csv', nrows=1000)

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '2013 [YR2013]'],
#       dtype='object')

# %%
df_pivot = df.pivot(index='Country Name', columns='Series Name', values='2013 [YR2013]')
df_pivot.head()
# Out:
# Series Name  2005 PPP conversion factor, GDP (LCU per international $)  \
# Country Name
# Afghanistan                                                  ..
#
# Series Name  2005 PPP conversion factor, private consumption (LCU per international $)  \
# Country Name
# Afghanistan                                                  ..
#
# Series Name  ARI treatment (% of children under 5 taken to a health provider)  \
# Country Name
# Afghanistan                                                  ..
#
# Series Name  Access to clean fuels and technologies for cooking  (% of population)  \
# Country Name
# Afghanistan                                               26.17
#
# Series Name  Access to electricity (% of population)  \
# Country Name
# Afghanistan                         67.2595520019531
#
# Series Name  Access to electricity, rural (% of rural population)  \
# Country Name
# Afghanistan                                    58.4236674312945
#
# ...
